# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

# %%
load_dotenv()
os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')

# %%
def add(a: float, b: float) -> float:
    """Calculates the sum of two numbers.

    :param a: The first number to be added (addend).
    :type a: float
    :param b: The second number to be added (addend).
    :type b: float
    
    :returns: The resulting sum of the two inputs.
    :rtype: float
    
    .. code-block:: python

        # Example Usage with doctest format
        >>> add(3, 6)
        9.0
        >>> add(2.1, 1.3)
        3.4
    """
    return a + b

# %%
llm = ChatGroq(model = 'openai/gpt-oss-120b')
llm_bind = llm.bind_tools([add])

# %%
result = llm_bind.invoke("What is 4.1 plus 3.2")

# %%
result.model_dump()
# Out:
# {'content': '',
#  'additional_kwargs': {'reasoning_content': 'User asks simple addition: 4.1 + 3.2 = 7.3. Could compute manually, but we have add function. Use it.',
#   'tool_calls': [{'id': 'fc_b84f6d75-ce6e-421f-a5aa-5623db60c865',
#     'function': {'arguments': '{"a":4.1,"b":3.2}', 'name': 'add'},
#     'type': 'function'}]},
#  'response_metadata': {'token_usage': {'completion_tokens': 71,
#    'prompt_tokens': 241,
#    'total_tokens': 312,
#    'completion_time': 0.164177304,
#    'completion_tokens_details': {'reasoning_tokens': 34},
#    'prompt_time': 0.012409547,
#    'prompt_tokens_details': None,
#    'queue_time': 0.026121044,
#    'total_time': 0.176586851},
#   'model_name': 'openai/gpt-oss-120b',
#   'system_fingerprint': 'fp_4867cb64c5',
#   'service_tier': 'on_demand',
#   'finish_reason': 'tool_calls',
#   'logprobs': None,
#   'model_provider': 'groq'},
#  'type': 'ai',
#  'name': None,
#  'id': 'lc_run--638882aa-d9ac-43a1-a1be-21715fdf5d64-0',
# ...

# %%
result.tool_calls
# Out:
# [{'name': 'add',
#   'args': {'a': 4.1, 'b': 3.2},
#   'id': 'fc_b84f6d75-ce6e-421f-a5aa-5623db60c865',
#   'type': 'tool_call'}]
